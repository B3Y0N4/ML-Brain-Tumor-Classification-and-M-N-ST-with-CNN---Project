# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras.utils import to_categorical
(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()

# normalize data
train_images = train_images / 255.0
test_images = test_images / 255.0

# define model architecture
model = models.Sequential()
model.add(layers.Conv2D(6, (5,5), padding='same', activation='relu', input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(16,(5,5), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(120, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# compile model with optimizer, loss function, and metrics
opt = Adam()
model.compile(loss=categorical_crossentropy,
              optimizer= opt,
              metrics=['accuracy'])
# one-hot encode the labels
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)
# train model
history = model.fit(train_images, train_labels, epochs=20,
                    validation_data=(test_images,test_labels))

# evaluate model on test set
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest Başarımı: ', test_acc)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 52s 27ms/step - loss: 0.1699 - accuracy: 0.9484 - val_loss: 0.0654 - val_accuracy: 0.9790
# Epoch 2/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0573 - accuracy: 0.9822 - val_loss: 0.0499 - val_accuracy: 0.9838
# Epoch 3/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0418 - accuracy: 0.9866 - val_loss: 0.0386 - val_accuracy: 0.9865
# Epoch 4/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0330 - accuracy: 0.9892 - val_loss: 0.0380 - val_accuracy: 0.9881
# Epoch 5/20
# 1875/1875 [==============================] - 45s 24ms/step - loss: 0.0262 - accuracy: 0.9916 - val_loss: 0.0312 - val_accuracy: 0.9903
# Epoch 6/20
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0213 - accuracy: 0.9930 - val_loss: 0.0300 - val_accuracy: 0.9898
# Epoch 7/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0182 - accuracy: 0.9939 - val_loss: 0.0282 - val_accuracy: 0.9908
# Epoch 8/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0152 - accuracy: 0.9951 - val_loss: 0.0350 - val_accuracy: 0.9903
# Epoch 9/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0294 - val_accuracy: 0.9906
# Epoch 10/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0114 - accuracy: 0.9960 - val_loss: 0.0301 - val_accuracy: 0.9903
# Epoch 11/20
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0360 - val_accuracy: 0.9912
# Epoch 12/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0433 - val_accuracy: 0.9904
# Epoch 13/20
# 1875/1875 [==============================] - 46s 24ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 0.0420 - val_accuracy: 0.9900
# Epoch 14/20
# 1875/1875 [==============================] - 50s 27ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0347 - val_accuracy: 0.9911
# Epoch 15/20
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0364 - val_accuracy: 0.9918
# Epoch 16/20
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0427 - val_accuracy: 0.9904
# Epoch 17/20
# 1875/1875 [==============================] - 47s 25ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0444 - val_accuracy: 0.9896
# Epoch 18/20
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0476 - val_accuracy: 0.9903
# Epoch 19/20
# 1875/1875 [==============================] - 48s 26ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0411 - val_accuracy: 0.9901
# Epoch 20/20
# 1875/1875 [==============================] - 49s 26ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0437 - val_accuracy: 0.9901
# 313/313 - 2s - loss: 0.0437 - accuracy: 0.9901 - 2s/epoch - 8ms/step
#
# Test Başarımı:  0.9901000261306763
