# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# MNIST veri kümesini yükleyin ve önişleme yapın
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Girdi şeklini (28, 28, 1) olarak değiştirin
x_train = x_train.reshape((len(x_train), 28, 28, 1))
x_test = x_test.reshape((len(x_test), 28, 28, 1))

# Modeli oluşturun
def create_model():
    model = models.Sequential()
    model.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1)))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Flatten())
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(10, activation='softmax'))
    return model

model = create_model()

# Modeli derleyin ve eğitin
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 938/938 [==============================] - 149s 155ms/step - loss: 0.1445 - accuracy: 0.9595 - val_loss: 0.0565 - val_accuracy: 0.9849
# Epoch 2/10
# 938/938 [==============================] - 144s 153ms/step - loss: 0.0616 - accuracy: 0.9825 - val_loss: 0.0485 - val_accuracy: 0.9871
# Epoch 3/10
# 938/938 [==============================] - 142s 152ms/step - loss: 0.0487 - accuracy: 0.9868 - val_loss: 0.0318 - val_accuracy: 0.9912
# Epoch 4/10
# 938/938 [==============================] - 147s 157ms/step - loss: 0.0384 - accuracy: 0.9889 - val_loss: 0.0425 - val_accuracy: 0.9888
# Epoch 5/10
# 938/938 [==============================] - 148s 158ms/step - loss: 0.0365 - accuracy: 0.9899 - val_loss: 0.1049 - val_accuracy: 0.9762
# Epoch 6/10
# 938/938 [==============================] - 145s 155ms/step - loss: 0.0314 - accuracy: 0.9914 - val_loss: 0.0531 - val_accuracy: 0.9894
# Epoch 7/10
# 938/938 [==============================] - 146s 155ms/step - loss: 0.0271 - accuracy: 0.9927 - val_loss: 0.0401 - val_accuracy: 0.9906
# Epoch 8/10
# 938/938 [==============================] - 148s 158ms/step - loss: 0.0234 - accuracy: 0.9936 - val_loss: 0.0333 - val_accuracy: 0.9916
# Epoch 9/10
# 938/938 [==============================] - 144s 154ms/step - loss: 0.0256 - accuracy: 0.9935 - val_loss: 0.0390 - val_accuracy: 0.9918
# Epoch 10/10
# 938/938 [==============================] - 146s 155ms/step - loss: 0.0178 - accuracy: 0.9951 - val_loss: 0.0379 - val_accuracy: 0.9917
