# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D, AveragePooling2D, Flatten, Dense

# Load the MNIST dataset
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values to be between 0 and 1
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Reshape the data to have a single color channel
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert the labels to one-hot encoded vectors
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Define the LeNet-5 model
model = Sequential()
model.add(Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1)))
model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=16, kernel_size=(5, 5), activation='relu'))
model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(units=120, activation='relu'))
model.add(Dense(units=84, activation='relu'))
model.add(Dense(units=10, activation='softmax'))

# Compile the model
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train,
          batch_size=128,
          epochs=10,
          verbose=1,
          validation_data=(x_test, y_test))

# Evaluate the model
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 469/469 [==============================] - 37s 72ms/step - loss: 0.3861 - accuracy: 0.8853 - val_loss: 0.1400 - val_accuracy: 0.9575
# Epoch 2/10
# 469/469 [==============================] - 27s 57ms/step - loss: 0.1197 - accuracy: 0.9632 - val_loss: 0.0833 - val_accuracy: 0.9750
# Epoch 3/10
# 469/469 [==============================] - 26s 56ms/step - loss: 0.0811 - accuracy: 0.9751 - val_loss: 0.0685 - val_accuracy: 0.9777
# Epoch 4/10
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0645 - accuracy: 0.9799 - val_loss: 0.0510 - val_accuracy: 0.9824
# Epoch 5/10
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0541 - accuracy: 0.9832 - val_loss: 0.0443 - val_accuracy: 0.9853
# Epoch 6/10
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0460 - accuracy: 0.9859 - val_loss: 0.0445 - val_accuracy: 0.9859
# Epoch 7/10
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0404 - accuracy: 0.9872 - val_loss: 0.0399 - val_accuracy: 0.9864
# Epoch 8/10
# 469/469 [==============================] - 27s 56ms/step - loss: 0.0358 - accuracy: 0.9890 - val_loss: 0.0403 - val_accuracy: 0.9874
# Epoch 9/10
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0307 - accuracy: 0.9899 - val_loss: 0.0352 - val_accuracy: 0.9869
# Epoch 10/10
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0283 - accuracy: 0.9908 - val_loss: 0.0309 - val_accuracy: 0.9896
# Test loss: 0.030911745503544807
# Test accuracy: 0.9896000027656555
