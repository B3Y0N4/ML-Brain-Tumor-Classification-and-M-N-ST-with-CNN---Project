# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Import required libraries
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
# !ls "/gdrive/MyDrive"

# %%
# Define the path to the brain tumor data on your Google Drive
data_path = '/gdrive/My Drive/brainTumorClassification'

# %%
# Define the size of the images
img_size = 32

# %%
# Initialize the data and label arrays
data = []
labels = []
categories = os.listdir(data_path)

# %%
# Loop through each category and load the images
for category in categories:
    path = os.path.join(data_path, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        img_array = cv2.resize(img_array, (img_size, img_size))
        data.append(img_array)
        labels.append(label_dict[category])
# Out:
# Error loading image /gdrive/My Drive/brainTumorClassification/Testing/glioma_tumor
# Error loading image /gdrive/My Drive/brainTumorClassification/Testing/pituitary_tumor
# Error loading image /gdrive/My Drive/brainTumorClassification/Testing/no_tumor
# Error loading image /gdrive/My Drive/brainTumorClassification/Testing/meningioma_tumor
# Error loading image /gdrive/My Drive/brainTumorClassification/Training/glioma_tumor
# Error loading image /gdrive/My Drive/brainTumorClassification/Training/no_tumor
# Error loading image /gdrive/My Drive/brainTumorClassification/Training/meningioma_tumor
# Error loading image /gdrive/My Drive/brainTumorClassification/Training/pituitary_tumor

# %%
# Convert the data and labels to NumPy arrays
data = np.array(data) / 255.0
labels = to_categorical(labels)

# %%
# Convert the data and labels to NumPy arrays
data = np.array(data) / 255.0
labels = to_categorical(labels)

# %%
# Define the LeNet model
model = tf.keras.Sequential([
    Conv2D(6, (5, 5), activation='relu', input_shape=(img_size, img_size, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(16, (5, 5), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(120, activation='relu'),
    Dense(84, activation='relu'),
    Dense(len(categories), activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(train_data.reshape(-1, img_size, img_size, 1), train_labels, epochs=10, validation_data=(test_data.reshape(-1, img_size, img_size, 1), test_labels))
